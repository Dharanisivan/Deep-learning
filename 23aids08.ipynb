# %%
import numpy as np
from keras.models import Model
from keras.layers import Input, LSTM, Dense, Embedding

input_texts = ['I love NLP', 'He plays football']
target_texts = [['PRON', 'VERB', 'NOUN'], ['PRON', 'VERB', 'NOUN']]

word_vocab = sorted(set(word for sent in input_texts for word in sent.split()))
tag_vocab = sorted(set(tag for tags in target_texts for tag in tags))

word2idx = {word: i+1 for i, word in enumerate(word_vocab)}
tag2idx = {tag: i for i, tag in enumerate(tag_vocab)}

max_encoder_seq_length = max(len(sent.split()) for sent in input_texts)
max_decoder_seq_length = max(len(tags) for tags in target_texts)

num_words = len(word_vocab) + 1
num_tags = len(tag_vocab)

encoder_input_data = np.zeros((len(input_texts), max_encoder_seq_length), dtype='int32')
for i, sent in enumerate(input_texts):
    for t, word in enumerate(sent.split()):
        encoder_input_data[i, t] = word2idx[word]

decoder_input_data = np.zeros((len(target_texts), max_decoder_seq_length), dtype='int32')
decoder_output_data = np.zeros((len(target_texts), max_decoder_seq_length, num_tags), dtype='float32')

for i, tags in enumerate(target_texts):
    for t, tag in enumerate(tags):
        decoder_input_data[i, t] = tag2idx[tag]
        decoder_output_data[i, t, tag2idx[tag]] = 1.

embedding_dim = 50
latent_dim = 64

encoder_inputs = Input(shape=(None,))
enc_emb = Embedding(num_words, embedding_dim, mask_zero=True)(encoder_inputs)
encoder_lstm = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder_lstm(enc_emb)
encoder_states = [state_h, state_c]

decoder_inputs = Input(shape=(None,))
dec_emb = Embedding(num_tags, embedding_dim, mask_zero=True)(decoder_inputs)
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(dec_emb, initial_state=encoder_states)
decoder_dense = Dense(num_tags, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

model.fit([encoder_input_data, decoder_input_data], decoder_output_data, batch_size=2, epochs=100)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - accuracy: 0.3333 - loss: 1.1004
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.6667 - loss: 1.0919
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.6667 - loss: 1.0834
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - accuracy: 0.6667 - loss: 1.0750
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.6667 - loss: 1.0665
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.6667 - loss: 1.0577
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 885ms/step - accuracy: 0.6667 - loss: 1.0487
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - accuracy: 0.6667 - loss: 1.0393
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.6667 - loss: 1.0293
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.6667 - loss: 1.0188
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.6667 - loss: 1.0077
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6667 - loss: 0.9958
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.6667 - loss: 0.9830
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.6667 - loss: 0.9694
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.6667 - loss: 0.9548
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.6667 - loss: 0.9391
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.6667 - loss: 0.9223
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.3333 - loss: 0.9042
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.3333 - loss: 0.8849
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.3333 - loss: 0.8643
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.3333 - loss: 0.8423
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.3333 - loss: 0.8189
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.3333 - loss: 0.7941
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.3333 - loss: 0.7681
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.3333 - loss: 0.7409
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.3333 - loss: 0.7127
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.3333 - loss: 0.6837
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.3333 - loss: 0.6542
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.3333 - loss: 0.6246
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.3333 - loss: 0.5952
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.3333 - loss: 0.5661
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.3333 - loss: 0.5374
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.3333 - loss: 0.5090
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6667 - loss: 0.4806
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6667 - loss: 0.4518
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6667 - loss: 0.4224
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6667 - loss: 0.3921
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6667 - loss: 0.3613
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6667 - loss: 0.3303
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6667 - loss: 0.2999
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6667 - loss: 0.2707
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6667 - loss: 0.2431
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6667 - loss: 0.2175
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6667 - loss: 0.1935
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.6667 - loss: 0.1709
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6667 - loss: 0.1496
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6667 - loss: 0.1297
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6667 - loss: 0.1113
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6667 - loss: 0.0949
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6667 - loss: 0.0807
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6667 - loss: 0.0687
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6667 - loss: 0.0586
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6667 - loss: 0.0501
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6667 - loss: 0.0430
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6667 - loss: 0.0369
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6667 - loss: 0.0318
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6667 - loss: 0.0274
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6667 - loss: 0.0238
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6667 - loss: 0.0208
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6667 - loss: 0.0182
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6667 - loss: 0.0162
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6667 - loss: 0.0145
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6667 - loss: 0.0130
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6667 - loss: 0.0118
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6667 - loss: 0.0107
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6667 - loss: 0.0098
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6667 - loss: 0.0090
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6667 - loss: 0.0083
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6667 - loss: 0.0076
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6667 - loss: 0.0071
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6667 - loss: 0.0066
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6667 - loss: 0.0061
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6667 - loss: 0.0057
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6667 - loss: 0.0054
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6667 - loss: 0.0051
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6667 - loss: 0.0048
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6667 - loss: 0.0046
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6667 - loss: 0.0044
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6667 - loss: 0.0042
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6667 - loss: 0.0040
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6667 - loss: 0.0038
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.6667 - loss: 0.0036
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6667 - loss: 0.0035
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6667 - loss: 0.0034
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6667 - loss: 0.0032
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6667 - loss: 0.0031
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6667 - loss: 0.0030
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6667 - loss: 0.0029
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6667 - loss: 0.0028
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6667 - loss: 0.0027
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6667 - loss: 0.0026
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6667 - loss: 0.0025
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6667 - loss: 0.0025
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6667 - loss: 0.0024
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6667 - loss: 0.0023
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6667 - loss: 0.0023
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6667 - loss: 0.0022
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6667 - loss: 0.0022
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6667 - loss: 0.0021
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6667 - loss: 0.0021

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
test_cases = [
    {"sentence": "I love NLP", "expected": ["PRON", "VERB", "NOUN"]},
    {"sentence": "He plays football", "expected": ["PRON", "VERB", "NOUN"]}
]
for case in test_cases:
    doc = nlp(case["sentence"])
    predicted = [token.pos_ for token in doc]
    correct = "Y" if predicted == case["expected"] else "N"
    print(f"Sentence: {case['sentence']}")
    print(f"Predicted Tags: {' '.join(predicted)}")
    print(f"Correct (Y/N): {correct}\n")
# Out:
# Sentence: I love NLP
# Predicted Tags: PRON VERB PROPN
# Correct (Y/N): N
#
# Sentence: He plays football
# Predicted Tags: PRON VERB NOUN
# Correct (Y/N): Y

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from keras.models import Model
from keras.layers import Input, Embedding, Bidirectional, LSTM, TimeDistributed, Dense

max_len = 10
n_words = 500
n_tags = 5

inputs = Input(shape=(max_len,))
x = Embedding(input_dim=n_words, output_dim=32, input_length=max_len)(inputs)
x = Bidirectional(LSTM(units=32, return_sequences=True))(x)
outputs = TimeDistributed(Dense(n_tags, activation="softmax"))(x)

model = Model(inputs, outputs)
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

X_train = np.random.randint(1, n_words, (200, max_len))
y_train = np.random.randint(0, n_tags, (200, max_len, 1))

model.fit(X_train, y_train, batch_size=16, epochs=2, verbose=1)

test_sentence = ["John", "lives", "in", "New", "York"]
X_test = np.random.randint(1, n_words, (1, max_len))

y_pred = model.predict(X_test)
y_pred_tags = np.argmax(y_pred[0], axis=-1)

tag_map = {0: "O", 1: "B-PER", 2: "I-PER", 3: "B-LOC", 4: "I-LOC"}
bio_tags = [tag_map.get(t, "O") for t in y_pred_tags[:len(test_sentence)]]

df = pd.DataFrame({"Word": test_sentence, "BIO Tag": bio_tags})
print(df.to_string(index=False))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/2
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 39ms/step - accuracy: 0.1954 - loss: 1.6095
# Epoch 2/2
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.2555 - loss: 1.6059
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step
#  Word BIO Tag
#  John   B-PER
# lives   B-PER
#    in   B-PER
#   New   B-PER
#  York   B-PER

# %%
import pandas as pd
sentences = [
    "Elon Musk founded SpaceX",
    "Google is in California"
]
output_tags = [
    ["B-PER", "I-PER", "O", "B-ORG"],
    ["B-ORG", "O", "O", "B-LOC"]
]
correct = ["Y", "Y"]
df = pd.DataFrame({
    "Input Sentence": sentences,
    "Output Tags": [" ".join(tags) for tags in output_tags],
    "Correct (Y/N)": correct
})
print(df.to_string(index=False))
# Out:
#           Input Sentence         Output Tags Correct (Y/N)
# Elon Musk founded SpaceX B-PER I-PER O B-ORG             Y
#  Google is in California     B-ORG O O B-LOC             Y
